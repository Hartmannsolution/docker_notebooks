# %% [markdown]
# ## Videos
# #### 00 Setup
# - [How to use docker. First 4 min is general docker, then specifically about this repo](https://youtu.be/9U_0NnlgvKg) **(11:36 min.)**
# - [How to install and get started](https://youtu.be/E8XhivDHXqA) **(5:00 min)**
# - [Using Jupyter notebooks and VS Code in this course](https://youtu.be/hW-zmaKi78U)**(11:13 min)**
# - [Course Introduction](https://youtu.be/5egWhX7CFgk) **(7:17 min)**
#
# #### 01 Python language
# - [Python language features and sequence types](https://youtu.be/U9cycDWNwG0) **(17:22 min)**
# - [Set and dicts](https://youtu.be/011WyBBXdMs) **(7:27 min)**
#
# #### 02 Python functions, modules etc
# - [Functions](https://youtu.be/dY_KewfiiiM) **(19:23)**
# - [Modules](https://youtu.be/VPIWWOSUc7A) **(27:00)**
# - [Command line arguments](https://youtu.be/c4jmQhv_f8I) **(10:00)**
# - [Working with files](https://youtu.be/xgjweBjiIFw) **(16:00)**
#
# #### 03 Classes, Exceptions and Plotting
# - [Classes](https://youtu.be/XNSv-0XsSZc)  **(14:45)**
# - [Exceptions](https://youtu.be/StjZDgmM0l4)  **(7:00)**
#
#
#
# #### 04 Numpy
# - [01 Multidimensional arrays and slicing 1](https://youtu.be/CsQwgm3uTcY)
# - [02 Operators and data types](https://youtu.be/6wiG6Y3u0Rw)
# - [03 Boolean masking and slicing](https://youtu.be/5Zw1Gv0XWQU)
# - [04 Real data example](https://youtu.be/gDGRs4qmEOs)
# - Ugens exercise er [her](04-Exercise.ipynb)
#
# #### 05 Pandas
# - [01 Pandas ](https://youtu.be/tkhpsDoGPg0) **(20:00)**
#
# #### 06 Requests and concurrency (NO LONGER PART OF CURRICULUM)
# - [01 requests and concurrency](https://youtu.be/wvcEShWGtpk) **(2:30:00)** Recordings from the classroom
#
# #### 07 Webscraping
# - [Web scraping with Beautiful Soup **14:55**](https://youtu.be/8JBsiAOUzYA)
# - [Regular Expressions **15:29**](https://youtu.be/hxGNtKjRwyw)
# - [Selenium **14:03**](https://youtu.be/A7u7RRDMEOE)
#
# #### 08 Machine learning
# - [01 Artificial Intelligence and Machine Learning **14:36**](https://www.youtube.com/watch?v=mM3sG4EpgAM&list=PLp907J1pTE7SvfvrKOYXTKNfp0z_4RuzC&index=2&ab_channel=ThomasHartmann)
# - [02 Feature space and OneHot encoding **10:37**](https://www.youtube.com/watch?v=BVY4hzQFZ84)
# - [03 Linear Algebra **11:28**](https://youtu.be/Q2_m8KJdMSk )
# - [04 Numerical data **19:33**](https://youtu.be/0nEj1px4JME )
#
# #### 09 Clustering
# - [01 Clustering with meanshift **9:35**](https://youtu.be/ylhcdYkwO7E)
# - [02 Clustering Titanic data **9:51**](https://youtu.be/B1E_cUUClU8 )
#
# #### 10 Classification
# - [01 Classification **7:06**](https://youtu.be/JsxlItdmUbM )
# - [02 Perceptrons **19:26**](https://youtu.be/LLZlLFdLfac )
# - [03 Classification with neural networks **10:20**](https://youtu.be/4RdOuTgZOHE)
# - [04 Classification with homemade neural network **14:54**](https://youtu.be/8oh2hTm6koQ)
# - [05 Neural networks 3 using Keras and Mnist dataset **14:19**](https://youtu.be/JfTYTggJH-A)
#
# #### 11 OpenCV image manipulation
# This video is a 14 module class over 2 hours. Fast forward through module 5, 6, 9, 10 and 14 and the final interview. Inside our docker environment we cant easily get access to the camera. If you want this you should install Anaconda instead and run you dev env locally.
# - [External video](https://www.youtube.com/watch?v=P4Z8_qe2Cu0&ab_channel=freeCodeCamp.org)
#
# #### 12 Text processing
# - [01 Preprocessing text **14:12**](https://youtu.be/n3Kw7oQAuCk)
# - [02 Word embeddings **6:53**](https://youtu.be/Q-2O9rUl5Co)
# - [03 IMDB example **10:03**](https://youtu.be/L3HPWozy5zg )
