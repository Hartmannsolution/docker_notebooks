# %% [markdown]
# # Plotting data

# %%
# Use the csv dataset
import csv
# read csv data into 2d array
data = []
with open('my_notebooks/data/corruption_data.csv') as corr:
    reader = csv.reader(corr)
    for row in reader:
        data.append(row)
# create dictionary with key = country name and value = list of corruption values from each year (use a dictionary comprehension)  
countries = {country[0]:country[1:] for country in data if country[0] != 'region_name'}
# Create a line plot for each of the nordic countries
# Create a class to hold the country name and the list of corruption values
# Add methods to get years and values respectively
# Add method to get avarage corruption value
# Add methods to return the worst and the best years values as object of a class with 3 properties: is_best:boolean, year, value
# Create a list of country objects and sort them by their avg corruption value
# Plot each (top ten countries only) countries worst and best values as a bar plot sorted on best values
# Create a bar plot with number of countries with avg values in range 0-25, 26-50, 51-75 and 76-100.
# Create a world map with pins of country name and avg. value

#country_avg = {country:sum(corr_list) for country, corr_list in countries.items()}
data
# Out:
# [['region_name',
#   '2021',
#   '2020',
#   '2019',
#   '2018',
#   '2017',
#   '2016',
#   '2015',
#   '2014',
#   '2013',
#   '2012'],
#  [' Denmark', '88', '88', '87', '88', '88', '90', '91', '92', '91', '90'],
#  [' New Zealand', '88', '88', '87', '87', '89', '90', '91', '91', '91', '90'],
#  [' Finland', '88', '85', '86', '85', '85', '89', '90', '89', '89', '90'],
#  [' Singapore', '85', '85', '85', '85', '84', '84', '85', '84', '86', '87'],
#  [' Sweden', '85', '85', '85', '85', '84', '88', '89', '87', '89', '88'],
#  ['  Switzerland', '84', '85', '85', '85', '85', '86', '86', '86', '85', '86'],
#  [' Norway', '85', '84', '84', '84', '85', '85', '87', '86', '86', '85'],
#  [' Netherlands', '82', '82', '82', '82', '82', '83', '87', '83', '83', '84'],
#  [' Germany', '80', '80', '80', '80', '81', '81', '81', '79', '78', '79'],
#  [' Luxembourg', '81', '80', '80', '81', '82', '81', '81', '82', '80', '80'],
# ...
