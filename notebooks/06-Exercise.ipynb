# %% [markdown]
# # Class Exercise
# 1. If not allready done register on OpenWetherMap and get an api key: https://home.openweathermap.org/api_keys
# 2. get the 5 day forecast data like this:
# ```python
# url = "http://api.openweathermap.org/data/2.5/forecast"
# req = requests.get(url, params={'q': 'Copenhagen,dk', 'mode': 'json',
#                                 'units': 'metric',
#                                 'appid': api_keys.OWM_API_KEY})
#
# req_json = json.loads(req.text)
# ```
# 3. create a function to get 'main' data from each list item in the forecast
# 4. find the lowest and highest temperature in celcius from the 5 days forecast
#
# ### City data
# 5. Download list of all cities here: http://bulk.openweathermap.org/sample/city.list.json.gz and unzip it
# 6. read the file and use json.load(file_name) to load the data into a dict
# 7. create a function to return a dict of key=countryname and value= list of all available cities
# 8. how many cities are in DK
# 9. create a function that returns a dictionary with avg temperatures of all cities provided in a list
# 10. what is the temperatur difference between Los Angeles and Copenhagen?

# %%
# !find api_keys.py
# Out:
# find: ‘api_keys.py’: No such file or directory

# %%
import requests
import json
from my_notebooks.my_modules.utils import api_keys
url = "http://api.openweathermap.org/data/2.5/forecast"
req = requests.get(url, params={'q': 'Copenhagen,dk', 'mode': 'json', 
                                'units': 'metric', 
                                'appid': api_keys.OPENWEATHERMAP_KEY})

#req_json = json.loads(req.text)
req.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1663599600,
#    'main': {'temp': 14.66,
#     'feels_like': 13.85,
#     'temp_min': 14.66,
#     'temp_max': 14.68,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1010,
#     'humidity': 64,
#     'temp_kf': -0.02},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 7.1, 'deg': 334, 'gust': 8.09},
#    'visibility': 10000,
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-19 15:00:00'},
#   {'dt': 1663610400,
#    'main': {'temp': 13.64,
#     'feels_like': 12.78,
#     'temp_min': 13.13,
#     'temp_max': 13.64,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1012,
#     'humidity': 66,
#     'temp_kf': 0.51},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 5.43, 'deg': 338, 'gust': 8.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-19 18:00:00'},
#   {'dt': 1663621200,
#    'main': {'temp': 12.64,
#     'feels_like': 11.63,
#     'temp_min': 12.64,
#     'temp_max': 12.64,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1013,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 4.41, 'deg': 353, 'gust': 7.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-19 21:00:00'},
#   {'dt': 1663632000,
#    'main': {'temp': 12.28,
#     'feels_like': 11.29,
#     'temp_min': 12.28,
#     'temp_max': 12.28,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1014,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 41},
#    'wind': {'speed': 4.09, 'deg': 355, 'gust': 7.03},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-20 00:00:00'},
#   {'dt': 1663642800,
#    'main': {'temp': 11.52,
#     'feels_like': 10.58,
#     'temp_min': 11.52,
#     'temp_max': 11.52,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 3.91, 'deg': 354, 'gust': 6.98},
#    'visibility': 10000,
#    'pop': 0.39,
#    'rain': {'3h': 0.11},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-20 03:00:00'},
#   {'dt': 1663653600,
#    'main': {'temp': 11.52,
#     'feels_like': 10.61,
#     'temp_min': 11.52,
#     'temp_max': 11.52,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1016,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.58, 'deg': 346, 'gust': 6.33},
#    'visibility': 10000,
#    'pop': 0.21,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-20 06:00:00'},
#   {'dt': 1663664400,
#    'main': {'temp': 13.64,
#     'feels_like': 12.63,
#     'temp_min': 13.64,
#     'temp_max': 13.64,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1017,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 4.98, 'deg': 358, 'gust': 6.33},
#    'visibility': 10000,
#    'pop': 0.07,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-20 09:00:00'},
#   {'dt': 1663675200,
#    'main': {'temp': 14.9,
#     'feels_like': 13.8,
#     'temp_min': 14.9,
#     'temp_max': 14.9,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 5.56, 'deg': 346, 'gust': 6.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-20 12:00:00'},
#   {'dt': 1663686000,
#    'main': {'temp': 14.62,
#     'feels_like': 13.57,
#     'temp_min': 14.62,
#     'temp_max': 14.62,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1019,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 5.52, 'deg': 342, 'gust': 5.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-20 15:00:00'},
#   {'dt': 1663696800,
#    'main': {'temp': 12.71,
#     'feels_like': 11.79,
#     'temp_min': 12.71,
#     'temp_max': 12.71,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1020,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 4.59, 'deg': 336, 'gust': 6.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-20 18:00:00'},
#   {'dt': 1663707600,
#    'main': {'temp': 12.45,
#     'feels_like': 11.58,
#     'temp_min': 12.45,
#     'temp_max': 12.45,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 4.1, 'deg': 331, 'gust': 6.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-20 21:00:00'},
#   {'dt': 1663718400,
#    'main': {'temp': 12.74,
#     'feels_like': 11.77,
#     'temp_min': 12.74,
#     'temp_max': 12.74,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 3.21, 'deg': 355, 'gust': 4.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-21 00:00:00'},
#   {'dt': 1663729200,
#    'main': {'temp': 11.25,
#     'feels_like': 10.18,
#     'temp_min': 11.25,
#     'temp_max': 11.25,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1023,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 2.83, 'deg': 7, 'gust': 3.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-21 03:00:00'},
#   {'dt': 1663740000,
#    'main': {'temp': 10.97,
#     'feels_like': 9.92,
#     'temp_min': 10.97,
#     'temp_max': 10.97,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 2.55, 'deg': 15, 'gust': 3.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-21 06:00:00'},
#   {'dt': 1663750800,
#    'main': {'temp': 13.12,
#     'feels_like': 11.95,
#     'temp_min': 13.12,
#     'temp_max': 13.12,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2.11, 'deg': 26, 'gust': 2.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-21 09:00:00'},
#   {'dt': 1663761600,
#    'main': {'temp': 14.62,
#     'feels_like': 13.39,
#     'temp_min': 14.62,
#     'temp_max': 14.62,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 0.85, 'deg': 28, 'gust': 1.53},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-21 12:00:00'},
#   {'dt': 1663772400,
#    'main': {'temp': 14.97,
#     'feels_like': 13.72,
#     'temp_min': 14.97,
#     'temp_max': 14.97,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 1.61, 'deg': 347, 'gust': 2.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-21 15:00:00'},
#   {'dt': 1663783200,
#    'main': {'temp': 13.09,
#     'feels_like': 11.94,
#     'temp_min': 13.09,
#     'temp_max': 13.09,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 2.5, 'deg': 335, 'gust': 2.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-21 18:00:00'},
#   {'dt': 1663794000,
#    'main': {'temp': 12.1,
#     'feels_like': 10.96,
#     'temp_min': 12.1,
#     'temp_max': 12.1,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 1.23, 'deg': 350, 'gust': 1.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-21 21:00:00'},
#   {'dt': 1663804800,
#    'main': {'temp': 11.68,
#     'feels_like': 10.52,
#     'temp_min': 11.68,
#     'temp_max': 11.68,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 0.84, 'deg': 288, 'gust': 0.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-22 00:00:00'},
#   {'dt': 1663815600,
#    'main': {'temp': 11.04,
#     'feels_like': 9.77,
#     'temp_min': 11.04,
#     'temp_max': 11.04,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1024,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.38, 'deg': 307, 'gust': 1.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-22 03:00:00'},
#   {'dt': 1663826400,
#    'main': {'temp': 11.31,
#     'feels_like': 9.98,
#     'temp_min': 11.31,
#     'temp_max': 11.31,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.2, 'deg': 85, 'gust': 0.53},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-22 06:00:00'},
#   {'dt': 1663837200,
#    'main': {'temp': 13.91,
#     'feels_like': 12.64,
#     'temp_min': 13.91,
#     'temp_max': 13.91,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 1.16, 'deg': 162, 'gust': 1.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-22 09:00:00'},
#   {'dt': 1663848000,
#    'main': {'temp': 15.4,
#     'feels_like': 14.25,
#     'temp_min': 15.4,
#     'temp_max': 15.4,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 19},
#    'wind': {'speed': 1.92, 'deg': 169, 'gust': 1.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-22 12:00:00'},
#   {'dt': 1663858800,
#    'main': {'temp': 15.44,
#     'feels_like': 14.42,
#     'temp_min': 15.44,
#     'temp_max': 15.44,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1022,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 3.55, 'deg': 176, 'gust': 3.3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-22 15:00:00'},
#   {'dt': 1663869600,
#    'main': {'temp': 14.33,
#     'feels_like': 13.46,
#     'temp_min': 14.33,
#     'temp_max': 14.33,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 21},
#    'wind': {'speed': 3.45, 'deg': 196, 'gust': 4.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-22 18:00:00'},
#   {'dt': 1663880400,
#    'main': {'temp': 13,
#     'feels_like': 12.03,
#     'temp_min': 13,
#     'temp_max': 13,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 2.47, 'deg': 235, 'gust': 3.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-22 21:00:00'},
#   {'dt': 1663891200,
#    'main': {'temp': 11.93,
#     'feels_like': 10.95,
#     'temp_min': 11.93,
#     'temp_max': 11.93,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 32},
#    'wind': {'speed': 3.08, 'deg': 228, 'gust': 4.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-23 00:00:00'},
#   {'dt': 1663902000,
#    'main': {'temp': 11.39,
#     'feels_like': 10.44,
#     'temp_min': 11.39,
#     'temp_max': 11.39,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1021,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.43, 'deg': 231, 'gust': 3.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-23 03:00:00'},
#   {'dt': 1663912800,
#    'main': {'temp': 11.77,
#     'feels_like': 10.86,
#     'temp_min': 11.77,
#     'temp_max': 11.77,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1020,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 1.93, 'deg': 216, 'gust': 2.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-23 06:00:00'},
#   {'dt': 1663923600,
#    'main': {'temp': 14.14,
#     'feels_like': 13.25,
#     'temp_min': 14.14,
#     'temp_max': 14.14,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1020,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.24, 'deg': 209, 'gust': 2.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-23 09:00:00'},
#   {'dt': 1663934400,
#    'main': {'temp': 15.91,
#     'feels_like': 15.02,
#     'temp_min': 15.91,
#     'temp_max': 15.91,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1019,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.69, 'deg': 207, 'gust': 3.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-23 12:00:00'},
#   {'dt': 1663945200,
#    'main': {'temp': 16.13,
#     'feels_like': 15.18,
#     'temp_min': 16.13,
#     'temp_max': 16.13,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.63, 'deg': 228, 'gust': 4.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-23 15:00:00'},
#   {'dt': 1663956000,
#    'main': {'temp': 14.18,
#     'feels_like': 13.19,
#     'temp_min': 14.18,
#     'temp_max': 14.18,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.15, 'deg': 238, 'gust': 4.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-23 18:00:00'},
#   {'dt': 1663966800,
#    'main': {'temp': 13.04,
#     'feels_like': 12.02,
#     'temp_min': 13.04,
#     'temp_max': 13.04,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 2.56, 'deg': 222, 'gust': 3.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-23 21:00:00'},
#   {'dt': 1663977600,
#    'main': {'temp': 12.72,
#     'feels_like': 11.61,
#     'temp_min': 12.72,
#     'temp_max': 12.72,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.62, 'deg': 218, 'gust': 3.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-24 00:00:00'},
#   {'dt': 1663988400,
#    'main': {'temp': 12.61,
#     'feels_like': 11.6,
#     'temp_min': 12.61,
#     'temp_max': 12.61,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1017,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.35, 'deg': 225, 'gust': 3.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-09-24 03:00:00'},
#   {'dt': 1663999200,
#    'main': {'temp': 12.51,
#     'feels_like': 11.51,
#     'temp_min': 12.51,
#     'temp_max': 12.51,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1017,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.99, 'deg': 221, 'gust': 2.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-24 06:00:00'},
#   {'dt': 1664010000,
#    'main': {'temp': 14.46,
#     'feels_like': 13.4,
#     'temp_min': 14.46,
#     'temp_max': 14.46,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2, 'deg': 197, 'gust': 2.76},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-24 09:00:00'},
#   {'dt': 1664020800,
#    'main': {'temp': 15.67,
#     'feels_like': 14.62,
#     'temp_min': 15.67,
#     'temp_max': 15.67,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1017,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.28, 'deg': 183, 'gust': 2.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-09-24 12:00:00'}],
#  'city': {'id': 2618425,
#   'name': 'Copenhagen',
#   'coord': {'lat': 55.6759, 'lon': 12.5655},
#   'country': 'DK',
#   'population': 15000,
#   'timezone': 7200,
#   'sunrise': 1663562933,
#   'sunset': 1663607908}}

# %% [markdown]
# # Handin Exercise 6
#
# Create a module containing a class: TextComparer with the following methods:
# 1. `__init__(self, url_list)`
# 2. `download(url,filename)` that stores the file on disk and raises NotFoundException when url returns 404
# 3. `multi_download()` uses threads to download multiple urls as text and stores filenames on a property of the TextComparer class object (Hint: use the download() method and create the filenames from the url or from the response object)
# 4. `__iter__()` returns an iterator
# 5. `__next__()` returns the next filename (and stops when there are no more)
# 6. `urllist_generator()` returns a generator to loop through the urls
# 7. `avg_vowels(text)` - a rough estimate on readability returns average number of vowels in the words of the text
# 8. `hardest_read()` reads all text from files in `filenames` and returns the filename of the text with the highest vowel score (use all the cpu cores on the computer for this work.
#
# ### Ex 2
# Create a notebook and import your module from above
# 1. Find 10 books on https://www.gutenberg.org/browse/scores/top and download them using an object of the class you just created before
# 2. Test the different methods of your class
# 3. Make a bar plot with a sorted list of books on x-axis and avg vowels on y-axis
